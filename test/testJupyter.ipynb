# %%
import myfunctions as fun
import numpy as np
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt

# %%
x, y = make_regression(n_samples=300, n_features=1, noise=10)
x.shape
y = y.reshape(y.shape[0],1)
y.shape

X = np.hstack((x, np.ones(x.shape)))

# %%
plt.scatter(x,y)

# %%
tetha = np.random.randn(X.shape[1],1)
tetha_final, cost_History = fun.gradient_Desc(X, y, tetha, learning_rate=0.01, nbr_iterations=1000)

prediction = fun.modele(X, tetha_final)

R = fun.coef_Determination(y, prediction)

# %%
plt.scatter(x, y)
plt.plot(x, prediction, c='r')

# %%
plt.plot(range(1000), cost_History)

# %%
R
# Out:
# 0.9863334272342374
